# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# # 1. Import All Necessary Libraries and Create File Paths

# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
from osgeo import gdal, gdal_array
import sys
import cv2
import tqdm

# %%
# folder path or file path constants that will be used in this project
# Root Directory (between 'F:' or 'D:'' depends on the external drive)
ROOT = "D:\\"

# Folder inside D:\\wildfire-sumatera-dataset
WILDFIRE_SUMATERA_DATASET_FOLDER_PATH = os.path.join(ROOT, 'wildfire-sumatera-dataset')


# Folders and metadatas inside D:\\wildfire-sumatera-dataset
WILDFIRE_SUMATERA_GEOTIFF_FOLDER_PATH = os.path.join(WILDFIRE_SUMATERA_DATASET_FOLDER_PATH, 'wildfire-sumatera-geotiff')
WILDFIRE_SUMATERA_IMAGE_FOLDER_PATH = os.path.join(WILDFIRE_SUMATERA_DATASET_FOLDER_PATH, 'wildfire-sumatera-image')
WILDFIRE_SUMATERA_IMAGE_MASK_FOLDER_PATH = os.path.join(WILDFIRE_SUMATERA_DATASET_FOLDER_PATH, 'wildfire-sumatera-image-mask')
WILDFIRE_SUMATERA_IMAGE_MASK_TFRECORD_FOLDER_PATH = os.path.join(WILDFIRE_SUMATERA_DATASET_FOLDER_PATH, 'wildfire-sumatera-image-mask-tfrecords')

# Files (.csv) and metadatas inside D:\\wildfire-sumatera-dataset
METADATA_LANDSAT_8_FILE_PATH = os.path.join(WILDFIRE_SUMATERA_DATASET_FOLDER_PATH, 'metadata_landsat_8.csv')
METADATA_SENTINEL_2_FILE_PATH = os.path.join(WILDFIRE_SUMATERA_DATASET_FOLDER_PATH, 'metadata_sentinel_2.csv')

# Folders inside D:\\wildfire-sumatera-dataset\\wildfire-sumatera-geotiff
SENTINEL_2_GEOTIFF_FOLDER_PATH = os.path.join(WILDFIRE_SUMATERA_GEOTIFF_FOLDER_PATH, 'sentinel-2')
LANDSAT_8_GEOTIFF_FOLDER_PATH = os.path.join(WILDFIRE_SUMATERA_GEOTIFF_FOLDER_PATH, 'landsat-8')

# Folders inside D:\\wildfire-sumatera-dataset\\wildfire-sumatera-image
SENTINEL_2_IMAGE_FOLDER_PATH = os.path.join(WILDFIRE_SUMATERA_IMAGE_FOLDER_PATH, 'sentinel-2')
LANDSAT_8_IMAGE_FOLDER_PATH = os.path.join(WILDFIRE_SUMATERA_IMAGE_FOLDER_PATH, 'landsat-8')

# Folders inside D:\\wildfire-sumatera-dataset\\wildfire-sumatera-geotiff\\landsat-8
LANDSAT_8_PREFIRE_GEOTIFF_FOLDER_PATH = os.path.join(LANDSAT_8_GEOTIFF_FOLDER_PATH, 'prefire')
LANDSAT_8_POSTFIRE_GEOTIFF_FOLDER_PATH = os.path.join(LANDSAT_8_GEOTIFF_FOLDER_PATH, 'postfire')

# Folders inside D:\\wildfire-sumatera-dataset\\wildfire-sumatera-geotiff\\sentinel-2
SENTINEL_2_PREFIRE_GEOTIFF_FOLDER_PATH = os.path.join(SENTINEL_2_GEOTIFF_FOLDER_PATH, 'prefire')
SENTINEL_2_POSTFIRE_GEOTIFF_FOLDER_PATH = os.path.join(SENTINEL_2_GEOTIFF_FOLDER_PATH, 'postfire')

# Folders inside D:\\wildfire-sumatera-dataset\\wildfire-sumatera-image-mask
SENTINEL_2_IMAGE_MASK_FOLDER_PATH = os.path.join(WILDFIRE_SUMATERA_IMAGE_MASK_FOLDER_PATH, 'sentinel-2')
LANDSAT_8_IMAGE_MASK_FOLDER_PATH = os.path.join(WILDFIRE_SUMATERA_IMAGE_MASK_FOLDER_PATH, 'landsat-8')

# Folders inside
SENTINEL_2_IMAGE_MASK_TFRECORD_FOLDER_PATH = os.path.join(WILDFIRE_SUMATERA_IMAGE_MASK_TFRECORD_FOLDER_PATH, 'sentinel-2')
LANDSAT_8_IMAGE_MASK_TFRECORD_FOLDER_PATH = os.path.join(WILDFIRE_SUMATERA_IMAGE_MASK_TFRECORD_FOLDER_PATH, 'landsat-8')

dirs = [
    WILDFIRE_SUMATERA_DATASET_FOLDER_PATH,
    WILDFIRE_SUMATERA_GEOTIFF_FOLDER_PATH, 
    WILDFIRE_SUMATERA_IMAGE_FOLDER_PATH,
    WILDFIRE_SUMATERA_IMAGE_MASK_FOLDER_PATH,
    WILDFIRE_SUMATERA_IMAGE_MASK_TFRECORD_FOLDER_PATH,
    
    SENTINEL_2_GEOTIFF_FOLDER_PATH, 
    LANDSAT_8_GEOTIFF_FOLDER_PATH,
    SENTINEL_2_IMAGE_FOLDER_PATH,
    LANDSAT_8_IMAGE_FOLDER_PATH,
    
    LANDSAT_8_PREFIRE_GEOTIFF_FOLDER_PATH,
    LANDSAT_8_POSTFIRE_GEOTIFF_FOLDER_PATH,
    SENTINEL_2_PREFIRE_GEOTIFF_FOLDER_PATH,
    SENTINEL_2_POSTFIRE_GEOTIFF_FOLDER_PATH,
    
    SENTINEL_2_IMAGE_MASK_FOLDER_PATH,
    LANDSAT_8_IMAGE_MASK_FOLDER_PATH,
    
    SENTINEL_2_IMAGE_MASK_TFRECORD_FOLDER_PATH,
    LANDSAT_8_IMAGE_MASK_TFRECORD_FOLDER_PATH,
]

for dir_ in dirs:
    if not os.path.exists(dir_):
        os.mkdir(dir_)
        print(f"{dir_} has been created")
    else:
        print(f"{dir_} already exist")
# Out:
# D:\wildfire-sumatera-dataset already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask-tfrecords already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\sentinel-2 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image\sentinel-2 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image\landsat-8 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\prefire already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\sentinel-2\prefire already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-geotiff\sentinel-2\postfire already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\sentinel-2 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask-tfrecords\sentinel-2 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask-tfrecords\landsat-8 already exist

# %% [markdown]
# # 2. Access The Dataset
# The dataset name is **data-total.csv** which contains all the necessary information about dates and location coordinates of a wildfire events in Indonesia.

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

wf_data  = pd.read_csv("../data-total.csv")
wf_data.columns

# rename columns
wf_data.rename(
    columns={
        'Lat': 'lat', 
        'Long': 'long', 
        'Satellite': 'satellite', 
        'Time_UTC': 'time_utc', 
        'Date': 'date', 
        'Source': 'source', 
        'PROVINSI': 'provinsi',
        'KAB_KOTA': 'kab_kota'
        }, 
    inplace=True,
    )

# adding '-' to date column values
wf_data.date = pd.to_datetime(wf_data.date, format="%Y%m%d")
wf_data.date = wf_data.date.astype('string')

# All provinces in sumatera
sumatera_provinces = [
    'SUMATERA UTARA',
    'JAMBI',
    'RIAU',
    'SUMATERA BARAT',
    'SUMATERA SELATAN',
    'BENGKULU',
    'LAMPUNG',
    'ACEH',
    ]

# create filter so that only events in sumatera will be returned.
sumatera_filter = wf_data['provinsi'].apply(lambda x: x in sumatera_provinces) 
sumatera_only = wf_data.loc[sumatera_filter]

display(sumatera_only.info())
display(sumatera_only.provinsi.unique())
display(sumatera_only.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7839 entries, 1 to 39670
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lat        7839 non-null   float64
#  1   long       7839 non-null   float64
#  2   satellite  7839 non-null   object
#  3   time_utc   7839 non-null   object
#  4   date       7839 non-null   string
#  5   source     7839 non-null   object
#  6   provinsi   7839 non-null   object
#  7   kab_kota   7839 non-null   object
#  8   kec2006    7830 non-null   object
#  9   desaa2006  7830 non-null   object
#  10  nama_kaw   930 non-null    object
# dtypes: float64(2), object(8), string(1)
# memory usage: 734.9+ KB
# None
# array(['LAMPUNG', 'RIAU', 'SUMATERA UTARA', 'SUMATERA BARAT',
#        'SUMATERA SELATAN', 'ACEH', 'JAMBI', 'BENGKULU'], dtype=object)
#        lat     long satellite     time_utc        date source        provinsi  \
# 1 -5.06259  105.101   LPN-NPP  06:11:04 AM  2016-08-24  LAPAN         LAMPUNG
# 4  1.18991  100.672   LPN-NPP  06:29:59 AM  2016-08-23  LAPAN            RIAU
# 5  2.31418  100.288   LPN-NPP  06:29:59 AM  2016-08-23  LAPAN  SUMATERA UTARA
# 6  1.41833  100.752   LPN-NPP  06:29:59 AM  2016-08-23  LAPAN            RIAU
# 8  1.38958  100.673   LPN-NPP  06:36:36 AM  2016-09-13  LAPAN            RIAU
#
#          kab_kota              kec2006              desaa2006 nama_kaw
# 1  LAMPUNG TENGAH            ANAK TUHA              BUMI JAYA      NaN
# 4      ROKAN HULU  KECAMATAN KAPENUHAN  UPT SP IV KOTO TENGAH      NaN
# 5     LABUHANBATU         PANAI TENGAH           SELAT BETING      NaN
# 6     ROKAN HILIR      KECAMATAN PUJUD          SIARANG ARANG      NaN
# 8     ROKAN HILIR      KECAMATAN PUJUD           TELUK NAYANG      NaN

# %%
# sort the data in based on 'date' column in ascending order
sumatera_only = sumatera_only.sort_values(
    by=['date'], 
    ascending=True,
    ignore_index=True,
)

sumatera_only.head()
# Out:
#        lat      long satellite     time_utc        date source provinsi  \
# 0  1.64968  100.8920   LPN-NPP  06:24:35 AM  2016-04-12  LAPAN     RIAU
# 1  1.64853  100.8840   LPN-NPP  06:24:35 AM  2016-04-12  LAPAN     RIAU
# 2  1.58003  100.8550   LPN-NPP  06:24:35 AM  2016-04-12  LAPAN     RIAU
# 3  4.27236   97.7478   LPN-NPP  06:24:35 AM  2016-04-12  LAPAN     ACEH
# 4  1.65664  100.8910   LPN-NPP  06:24:35 AM  2016-04-12  LAPAN     RIAU
#
#        kab_kota                  kec2006       desaa2006 nama_kaw
# 0   ROKAN HILIR  KECAMATAN BANGKO PUSAKO  SUNGAI MENASIB      NaN
# 1   ROKAN HILIR  KECAMATAN BANGKO PUSAKO  SUNGAI MENASIB      NaN
# 2   ROKAN HILIR    KECAMATAN TANAH PUTIH  BALAM SEMPURNA      NaN
# 3  ACEH TAMIANG             TAMIANG HULU   BATU BEDULANG      NaN
# 4   ROKAN HILIR  KECAMATAN BANGKO PUSAKO  SUNGAI MENASIB      NaN

# %% [markdown]
# # 3. Create All Functions for the Project and Constants

# %%
def get_img_as_array(filepath, dictionary):
    """
    :param filepath: location of the satellite bands
    :param dictionary: information about the image bands
    :return: dictionary containing name of the satellite bands as key and array of pixels as value  
    """
    os.chdir(filepath)
    print(filepath)
    band_imgs = {}
    for key, val in dictionary.items():
        # open the .tiff file
        if os.path.exists(filepath):
            tiff_file = gdal.Open(key)
            bands = key.split('_')
            for i, band in enumerate(bands):
                band_imgs[band] = tiff_file.GetRasterBand(i+1).ReadAsArray()
    
    return band_imgs

# %%
def save_satellite_image(bands=[], file_path=""):
    """
    :param bands: array of satellite image bands
    :param filepath: location of the image being stored
    :return: return result of the conversion (True which is 'success' or False which is 'failed') 
    """
    if not bands:
        print("bands cannot be empty")
        return 
    
    if not file_path:
        print("filename cannot be empty")
        return
    img = cv2.merge(bands)
    img *= 255
    cv2.imwrite(file_path, img)
    return True

# %%
LANDSAT_POSTFIRE_DICT = {
    'dnbr_b7': 2,
    'b5_b4': 2,
    'b3_b2': 2
}

SENTINEL_POSTFIRE_DICT = {
    'dnbr_b12': 2,
    'b8_b4': 2,
    'b3_b2': 2
}

# %% [markdown]
# # 4. Open Landsat CSV File

# %%
PNG_EXT = '.png'
landsat_df = pd.read_csv(METADATA_LANDSAT_8_FILE_PATH)
landsat_df.head()
# Out:
#                                 folder_paths_geotiff  mean_dnbr  median_dnbr  \
# 0  \wildfire-sumatera-dataset\wildfire-sumatera-g...   0.118657     0.092437
# 1  \wildfire-sumatera-dataset\wildfire-sumatera-g...   0.118892     0.092641
# 2  \wildfire-sumatera-dataset\wildfire-sumatera-g...   0.124600     0.095925
# 3  \wildfire-sumatera-dataset\wildfire-sumatera-g...   0.099432     0.074912
# 4  \wildfire-sumatera-dataset\wildfire-sumatera-g...   0.118605     0.092377
#
#    class_by_mean  class_by_median  image_condition  \
# 0              0                0                1
# 1              0                0                1
# 2              0                0                1
# 3              0                0                1
# 4              0                0                1
#
#                              folder_paths_image_mask
# 0  \wildfire-sumatera-dataset\wildfire-sumatera-i...
# 1  \wildfire-sumatera-dataset\wildfire-sumatera-i...
# 2  \wildfire-sumatera-dataset\wildfire-sumatera-i...
# 3  \wildfire-sumatera-dataset\wildfire-sumatera-i...
# 4  \wildfire-sumatera-dataset\wildfire-sumatera-i...

# %% [markdown]
# ## 4.1 Check Image Condition From All Bands
# Filter to check whether all of the array forms of each bands is not **None** or **empty**

# %%
landsat_image_condition = []
for index, row in landsat_df.iterrows():
    # open the image path
    condition = 1
    landsat_postfire_img_band = get_img_as_array(
        os.path.join(ROOT, row['folder_paths_geotiff']), 
        LANDSAT_POSTFIRE_DICT,
    )
    defect = [val is None for key, val in landsat_postfire_img_band.items()]            
    if np.sum(defect) > 0:
        condition=0
        print("defect detected")
    landsat_image_condition.append(condition)

# %%
landsat_df['image_condition'] = landsat_image_condition
landsat_df.to_csv(METADATA_LANDSAT_8_FILE_PATH, index=False)

# %% [markdown]
# ## 4.2 Binarized Image
# Save a file containing real images with their masks

# %%
for index, row in landsat_df.iterrows():
    print(row['folder_paths_geotiff'])
    if row['image_condition']:
        # create directory path
        directory = os.path.join(LANDSAT_8_IMAGE_MASK_FOLDER_PATH, str(index))
        print(directory)

        # check if the directory already exists
        if not os.path.exists(directory):
            os.mkdir(directory)
            print("{} has been created".format(directory))
        else:
            print("{} already exist".format(directory))
        
        # check if the image.png and mask.png already exists
        image_path = os.path.join(directory, 'image.png')
        mask_path = os.path.join(directory, 'mask.png')
        if os.path.exists(image_path) and os.path.exists(mask_path):
            print("{} and {} already exist".format(image_path, mask_path))
            continue
            
        # open the image path
        landsat_postfire_img_band = get_img_as_array(
            os.path.join(ROOT, row['folder_paths_geotiff']), 
            LANDSAT_POSTFIRE_DICT,
        )
        mask_binary = np.array(landsat_postfire_img_band['dnbr'], dtype=np.float32)
        mask_binary = np.where(mask_binary<0.05, 0, 255)
        # save image
        save_satellite_image([
            landsat_postfire_img_band['b2'], 
            landsat_postfire_img_band['b3'],
            landsat_postfire_img_band['b4'],], 
            os.path.join(directory, image_path))
        # save mask
        cv2.imwrite(os.path.join(directory, mask_path), mask_binary)
    else:
        print('image is broke')
# Out:
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\0
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\0
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\0 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\0\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\0\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\1
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\1
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\1 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\1\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\1\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\2
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\2
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\2 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\2\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\2\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\3
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\3
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\3 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\3\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\3\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\4
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\4
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\4 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\4\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\4\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\6
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\6
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\6 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\6\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\6\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\7
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\7
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\7 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\7\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\7\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\8
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\8
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\8 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\8\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\8\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\9
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\9
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\9 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\9\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\9\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\10
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\10
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\10 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\10\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\10\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\11
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\11
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\11 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\11\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\11\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\12
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\12
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\12 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\12\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\12\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\13
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\13
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\13 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\13\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\13\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\14
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\14
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\14 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\14\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\14\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\15
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\15
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\15 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\15\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\15\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\16
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\16
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\16 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\16\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\16\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\17
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\17
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\17 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\17\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\17\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\18
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\18
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\18 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\18\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\18\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\19
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\19
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\19 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\19\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\19\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\20
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\20
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\20 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\20\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\20\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\21
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\21
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\21 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\21\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\21\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\22
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\22
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\22 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\22\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\22\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\23
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\23
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\23 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\23\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\23\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\24
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\24
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\24 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\24\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\24\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\25
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\25
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\25 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\25\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\25\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\26
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\26
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\26 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\26\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\26\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\27
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\27
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\27 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\27\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\27\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\28
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\28
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\28 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\28\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\28\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\29
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\29
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\29 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\29\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\29\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\30
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\30
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\30 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\30\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\30\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\31
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\31
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\31 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\31\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\31\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\32
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\32
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\32 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\32\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\32\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\33
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\33
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\33 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\33\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\33\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\34
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\34
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\34 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\34\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\34\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\35
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\35
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\35 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\35\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\35\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\36
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\36
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\36 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\36\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\36\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\37
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\37
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\37 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\37\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\37\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\38
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\38
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\38 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\38\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\38\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\39
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\39
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\39 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\39\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\39\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\40
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\40
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\40 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\40\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\40\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\41
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\41
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\41 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\41\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\41\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\42
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\42
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\42 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\42\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\42\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\43
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\43
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\43 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\43\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\43\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\44
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\44
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\44 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\44\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\44\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\45
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\45
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\45 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\45\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\45\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\46
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\46
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\46 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\46\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\46\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\47
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\47
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\47 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\47\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\47\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\48
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\48
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\48 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\48\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\48\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\49
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\49
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\49 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\49\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\49\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\50
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\50
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\50 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\50\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\50\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\51
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\51
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\51 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\51\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\51\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\52
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\52
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\52 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\52\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\52\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\53
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\53
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\53 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\53\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\53\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\54
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\54
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\54 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\54\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\54\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\55
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\55
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\55 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\55\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\55\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\56
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\56
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\56 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\56\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\56\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\57
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\57
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\57 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\57\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\57\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\58
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\58
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\58 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\58\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\58\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\59
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\59
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\59 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\59\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\59\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\60
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\60
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\60 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\60\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\60\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\61
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\61
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\61 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\61\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\61\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\62
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\62
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\62 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\62\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\62\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\63
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\63
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\63 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\63\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\63\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\64
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\64
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\64 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\64\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\64\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\65
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\65
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\65 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\65\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\65\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\66
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\66
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\66 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\66\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\66\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\67
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\67
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\67 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\67\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\67\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\68
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\68
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\68 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\68\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\68\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\69
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\69
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\69 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\69\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\69\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\70
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\70
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\70 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\70\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\70\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\71
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\71
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\71 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\71\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\71\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\72
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\72
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\72 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\72\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\72\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\73
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\73
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\73 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\73\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\73\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\74
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\74
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\74 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\74\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\74\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\75
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\75
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\75 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\75\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\75\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\76
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\76
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\76 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\76\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\76\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\77
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\77
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\77 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\77\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\77\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\78
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\78
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\78 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\78\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\78\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\79
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\79
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\79 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\79\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\79\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\80
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\80
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\80 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\80\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\80\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\81
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\81
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\81 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\81\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\81\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\82
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\82
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\82 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\82\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\82\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\83
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\83
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\83 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\83\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\83\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\84
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\84
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\84 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\84\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\84\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\85
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\85
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\85 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\85\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\85\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\86
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\86
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\86 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\86\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\86\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\87
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\87
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\87 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\87\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\87\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\88
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\88
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\88 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\88\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\88\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\89
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\89
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\89 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\89\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\89\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\90
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\90
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\90 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\90\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\90\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\91
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\91
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\91 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\91\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\91\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\92
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\92
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\92 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\92\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\92\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\93
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\93
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\93 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\93\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\93\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\94
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\94
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\94 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\94\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\94\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\95
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\95
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\95 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\95\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\95\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\96
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\96
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\96 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\96\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\96\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\97
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\97
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\97 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\97\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\97\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\98
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\98
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\98 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\98\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\98\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\99
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\99
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\99 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\99\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\99\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\100
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\100
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\100 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\100\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\100\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\101
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\101
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\101 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\101\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\101\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\102
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\102
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\102 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\102\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\102\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\103
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\103
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\103 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\103\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\103\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\104
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\104
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\104 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\104\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\104\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\105
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\105
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\105 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\105\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\105\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\106
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\106
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\106 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\106\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\106\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\107
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\107
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\107 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\107\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\107\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\108
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\108
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\108 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\108\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\108\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\109
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\109
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\109 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\109\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\109\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\110
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\110
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\110 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\110\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\110\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\111
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\111
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\111 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\111\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\111\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\112
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\112
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\112 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\112\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\112\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\113
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\113
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\113 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\113\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\113\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\114
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\114
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\114 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\114\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\114\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\115
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\115
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\115 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\115\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\115\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\116
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\116
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\116 already exist
# ...
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5588
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5588 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5588\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5588\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5589
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5589
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5589 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5589\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5589\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5590
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5590
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5590 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5590\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5590\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5591
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5591
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5591 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5591\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5591\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5592
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5592
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5592 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5592\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5592\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5593
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5593
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5593 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5593\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5593\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5594
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5594
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5594 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5594\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5594\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5595
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5595
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5595 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5595\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5595\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5596
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5596
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5596 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5596\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5596\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5597
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5597
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5597 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5597\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5597\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5598
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5598
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5598 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5598\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5598\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5599
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5599
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5599 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5599\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5599\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5600
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5600
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5600 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5600\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5600\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5601
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5601
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5601 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5601\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5601\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5602
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5602
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5602 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5602\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5602\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5603
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5603
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5603 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5603\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5603\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5604
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5604
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5604 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5604\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5604\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5605
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5605
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5605 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5605\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5605\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5606
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5606
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5606 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5606\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5606\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5607
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5607
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5607 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5607\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5607\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5608
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5608
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5608 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5608\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5608\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5609
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5609
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5609 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5609\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5609\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5610
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5610
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5610 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5610\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5610\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5611
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5611
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5611 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5611\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5611\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5612
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5612
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5612 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5612\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5612\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5613
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5613
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5613 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5613\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5613\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5614
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5614
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5614 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5614\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5614\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5615
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5615
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5615 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5615\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5615\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5616
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5616
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5616 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5616\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5616\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5617
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5617
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5617 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5617\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5617\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5618
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5618
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5618 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5618\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5618\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5619
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5619
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5619 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5619\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5619\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5620
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5620
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5620 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5620\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5620\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5621
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5621
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5621 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5621\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5621\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5622
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5622
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5622 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5622\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5622\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5623
# image is broke
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5624
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5624
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5624 already exist
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5624\image.png and D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5624\mask.png already exist
# \wildfire-sumatera-dataset\wildfire-sumatera-geotiff\landsat-8\postfire\5625
# D:\wildfire-sumatera-dataset\wildfire-sumatera-image-mask\landsat-8\5625
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
#       6 print(directory)
#       8 # check if the directory already exists
# ----> 9 if not os.path.exists(directory):
#      10     os.mkdir(directory)
#      11     print("{} has been created".format(directory))
#
# File ~\AppData\Local\Programs\Python\Python38\lib\genericpath.py:19, in exists(path)
#      17 """Test whether a path exists.  Returns False for broken symbolic links"""
#      18 try:
# ---> 19     os.stat(path)
#      20 except (OSError, ValueError):
#      21     return False
#
# KeyboardInterrupt:

# %% [markdown]
# Create a new column that contains the location of images with their masks

# %%
landsat_8_image_mask_folders = [os.path.join('\\', 'wildfire-sumatera-dataset', 'wildfire-sumatera-image-mask', 'landsat-8', str(i)) for i in range(len(landsat_df.index))]
landsat_df['folder_paths_image_mask'] = landsat_8_image_mask_folders
landsat_df.to_csv(METADATA_LANDSAT_8_FILE_PATH, index=False)

# %% [markdown]
# ## 4.3 Clean Images by Area of Pixels and Save as PNG
# small area of pixels will be removed to reduce noise

# %%
for index, row in landsat_df.iterrows():
    if row['image_condition']:
        # create directory path
        directory = os.path.join(ROOT, row['folder_paths_image_mask'])
        print(directory)
        
        # check if the image.png and mask.png already exists
        cleaned_mask_path = os.path.join(directory, 'cleaned_mask.png')
        if os.path.exists(cleaned_mask_path):
            print("{} already exist".format(cleaned_mask_path))
            continue
        
        image = cv2.imread(os.path.join(directory, 'mask.png'))

        # convert image to grayscale
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        # apply GaussianBlur to the image
        blur = cv2.GaussianBlur(gray, (7, 7), 0)
        
        # create a binary representation of the image
        # thresholding means all pixels below T (threshold value) will be 0
        # else will be 255
        thresh = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
        
        # Filter using contour area and remove small noise
        cnts = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
        cnts = cnts[0] if len(cnts) == 2 else cnts[1]
        for c in cnts:
            area = cv2.contourArea(c)
            if area < 5500:
                cv2.drawContours(thresh, [c], -1, (0,0,0), -1)

        # Morph close and invert image
        kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (7,7))
        cleaned_mask = 255 - cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel, iterations=2)
        cv2.imwrite(os.path.join(directory, 'cleaned_mask{}'.format(PNG_EXT)), cleaned_mask)

# %% [markdown]
# # 5. Open Sentinel CSV File

# %%
PNG_EXT = '.png'
sentinel_df = pd.read_csv(METADATA_SENTINEL_2_FILE_PATH)
sentinel_df.head()

# %% [markdown]
# ## 5.1 Check Image Condition From All Bands
# Filter to check whether all of the array forms of each bands is not **None** or **empty**

# %%
sentinel_image_condition = []
for index, row in sentinel_df.iterrows():
    # open the image path
    condition = 1
    sentinel_postfire_img_band = get_img_as_array(
        os.path.join(ROOT, row['folder_paths_geotiff']), 
        SENTINEL_POSTFIRE_DICT,
    )
    defect = [val is None for key, val in sentinel_postfire_img_band.items()]            
    if np.sum(defect) > 0:
        condition=0
        print("defect detected")
    sentinel_image_condition.append(condition)

# %%
sentinel_df['image_condition'] = sentinel_image_condition
sentinel_df.to_csv(METADATA_SENTINEL_2_FILE_PATH, index=False)

# %% [markdown]
# ## 5.2 Binarized Image
# Save a file containing real images with their masks

# %%
for index, row in sentinel_df.iterrows():
    print(row['folder_paths_geotiff'])
    if row['image_condition']:
        # create directory path
        directory = os.path.join(SENTINEL_2_IMAGE_MASK_FOLDER_PATH, str(index))

        # check if the directory already exists
        if not os.path.exists(directory):
            os.mkdir(directory)
            print("{} has been created".format(directory))
        else:
            print("{} already exist".format(directory))

        # check if the image.png and mask.png already exists
        image_path = os.path.join(directory, 'image.png')
        mask_path = os.path.join(directory, 'mask.png')
        if os.path.exists(image_path) and os.path.exists(mask_path):
            print("{} and {} already exist".format(image_path, mask_path))
            continue

        # open the image path
        sentinel_postfire_img_band = get_img_as_array(
            os.path.join(ROOT, row['folder_paths_geotiff']), 
            SENTINEL_POSTFIRE_DICT,
        )
        mask_binary = np.array(sentinel_postfire_img_band['dnbr'], dtype=np.float32)
        mask_binary = np.where(mask_binary<0.05, 0, 255)        
        # save image
        save_satellite_image([
            sentinel_postfire_img_band['b2'], 
            sentinel_postfire_img_band['b3'],
            sentinel_postfire_img_band['b4'],], 
            os.path.join(directory, 'image{}'.format(PNG_EXT)))
        # save mask
        cv2.imwrite(os.path.join(directory, 'mask{}'.format(PNG_EXT)), mask_binary)
    else:
        print('image is broke')

# %%
sentinel_image_mask_folders = [os.path.join('\\', 'wildfire-sumatera-dataset', 'wildfire-sumatera-image-mask', 'sentinel-2', str(i)) for i in range(len(sentinel_df.index))]
sentinel_df['folder_paths_image_mask'] = sentinel_image_mask_folders
sentinel_df.to_csv(METADATA_SENTINEL_2_FILE_PATH, index=False)

# %% [markdown]
# ## 5.3 Clean Images by Area of Pixels and Save as PNG
# small area of pixels will be removed to reduce noise

# %%
for index, row in sentinel_df.iterrows():
    if row['image_condition']:
        # create directory path
        directory = os.path.join(ROOT, row['folder_paths_image_mask'])
        print(directory)

        
        # check if the image.png and mask.png already exists
        cleaned_mask_path = os.path.join(directory, 'cleaned_mask.png')
        if os.path.exists(cleaned_mask_path):
            print("{} already exist".format(cleaned_mask_path))
            continue
        
        image = cv2.imread(os.path.join(directory, 'mask.png'))

        # convert image to grayscale
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        # apply GaussianBlur to the image
        blur = cv2.GaussianBlur(gray, (7, 7), 0)
        
        # create a binary representation of the image
        # thresholding means all pixels below T (threshold value) will be 0
        # else will be 255
        thresh = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]
        # Filter using contour area and remove small noise
        cnts = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
        cnts = cnts[0] if len(cnts) == 2 else cnts[1]
        for c in cnts:
            area = cv2.contourArea(c)
            if area < 5500:
                cv2.drawContours(thresh, [c], -1, (0,0,0), -1)

        # Morph close and invert image
        kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (7,7))
        cleaned_mask = 255 - cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel, iterations=2)
        cv2.imwrite(os.path.join(directory, 'cleaned_mask{}'.format(PNG_EXT)), cleaned_mask)
